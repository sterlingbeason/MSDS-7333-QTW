# %% [markdown]
# # DS 7333 - Quantifying the World
# ## Case Study #3
#
# Sterling Beason, Sean Kennedy, Emil Ramos

# %%
import pandas as pd
from IPython.display import SVG

# IMPORTANT: install rpy2 v3.3.x
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri
from rpy2.robjects.conversion import localconverter

from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedShuffleSplit
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import tree
from sklearn.metrics import accuracy_score, precision_score
from sklearn.pipeline import Pipeline

# Recommended Installation: 'conda install python-graphviz' (should add 'graphviz' to PATH)
from graphviz import Source
import seaborn as sns

# %% [markdown]
# ### Import R Data and Convert to Pandas DataFrame

# %%
base = importr('base')
base.load("./Data/data.Rda")
rdf_List = base.mget(base.ls())

with localconverter(ro.default_converter + pandas2ri.converter):
    df = ro.conversion.rpy2py(rdf_List[0]) # convert 'emailDFrp' dataset
    
df = df.reset_index()
df = df.drop('index', 1)

df
# Out:
#      isSpam isRe underscore priority isInReplyTo sortedRec subPunc  \
# 0         F    T          F        F           T         T       F
# 1         F    F          F        F           F         T       F
# 2         F    F          F        F           F         T       F
# 3         F    F          F        F           F         T       F
# 4         F    T          F        F           F         T       F
# ...     ...  ...        ...      ...         ...       ...     ...
# 9343      T    F          F        F           F         T       F
# 9344      T    F          F        F           F         T       F
# 9345      T    F          F        F           F         F       F
# 9346      T    F          F        F           F         T       F
# 9347      T    F          F        F           F         T       F
#
#      multipartText hasImages isPGPsigned  ... subQuesCt numAtt numRec  \
# 0                F         F           F  ...         0    0.0      2
# 1                F         F           F  ...         0    0.0      1
# 2                F         F           F  ...         0    0.0      1
# 3                F         F           F  ...         0    0.0      0
# 4                F         F           F  ...         0    0.0      1
# ...            ...       ...         ...  ...       ...    ...    ...
# 9343             F         F           F  ...         1    0.0      1
# 9344             T         F           F  ...         0    1.0      1
# 9345             F         F           F  ...         0    0.0      1
# 9346             F         F           F  ...         0    0.0      1
# 9347             F         F           F  ...         0    0.0      1
#
#        perCaps  hour    perHTML  subBlanks  forwards  avgWordLen  numDlr
# 0     4.451039  11.0   0.000000  12.500000  0.000000    4.376623       3
# 1     7.491289  11.0   0.000000   8.000000  0.000000    4.555556       0
# 2     7.436096  12.0   0.000000   8.000000  0.000000    4.817164       0
# 3     5.090909  13.0   0.000000  18.918919  3.125000    4.714286       0
# 4     6.116643  13.0   0.000000  15.217391  6.451613    4.234940       0
# ...        ...   ...        ...        ...       ...         ...     ...
# 9343  8.572552  21.0  79.657111  13.793103  0.000000    4.700555       2
# 9344  9.436009  23.0   0.000000  10.526316  0.000000    4.904255       4
# 9345  2.418448   8.0   0.000000  20.000000  0.000000    4.703704       0
# 9346  7.795400  23.0   0.000000   5.263158  0.000000    5.252690      80
# 9347  4.783951   6.0   0.000000  14.285714  0.000000    4.823821       1
#
# [9348 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9348 entries, 0 to 9347
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   isSpam         9348 non-null   category
#  1   isRe           9348 non-null   category
#  2   underscore     9348 non-null   category
#  3   priority       9348 non-null   category
#  4   isInReplyTo    9348 non-null   category
#  5   sortedRec      9348 non-null   category
#  6   subPunc        9348 non-null   category
#  7   multipartText  9348 non-null   category
#  8   hasImages      9348 non-null   category
#  9   isPGPsigned    9348 non-null   category
#  10  subSpamWords   9341 non-null   category
#  11  noHost         9347 non-null   category
#  12  numEnd         9348 non-null   category
#  13  isYelling      9341 non-null   category
#  14  isOrigMsg      9348 non-null   category
#  15  isDear         9348 non-null   category
#  16  isWrote        9348 non-null   category
#  17  numLines       9348 non-null   int32
#  18  bodyCharCt     9348 non-null   int32
#  19  subExcCt       9348 non-null   int32
#  20  subQuesCt      9348 non-null   int32
#  21  numAtt         9348 non-null   float64
#  22  numRec         9348 non-null   int32
#  23  perCaps        9348 non-null   float64
#  24  hour           9348 non-null   float64
#  25  perHTML        9348 non-null   float64
#  26  subBlanks      9328 non-null   float64
#  27  forwards       9348 non-null   float64
#  28  avgWordLen     9348 non-null   float64
#  29  numDlr         9348 non-null   int32
# dtypes: category(17), float64(7), int32(6)
# memory usage: 887.2 KB

# %%
df.hour = df.hour.astype('category')

# %%
print(df.isna().any())
# Out:
# isSpam           False
# isRe             False
# underscore       False
# priority         False
# isInReplyTo      False
# sortedRec        False
# subPunc          False
# multipartText    False
# hasImages        False
# isPGPsigned      False
# subSpamWords      True
# noHost            True
# numEnd           False
# isYelling         True
# isOrigMsg        False
# isDear           False
# isWrote          False
# numLines         False
# bodyCharCt       False
# subExcCt         False
# subQuesCt        False
# numAtt           False
# numRec           False
# perCaps          False
# hour             False
# perHTML          False
# subBlanks         True
# forwards         False
# avgWordLen       False
# numDlr           False
# dtype: bool

# %% [markdown]
# There are 4 columns with NAs
#
# - subSpamWords (category)
#
# - noHost (category)
#
# - isYelling (category)
#
# - subBlanks (float)
#
# Let's analyze the categorical variables first:
#
# ***subSpamWords***

# %%
df.subSpamWords.unique()
# Out:
# [F, T, NaN]
# Categories (2, object): [F, T]

# %%
spam_na = df[df.subSpamWords.isna()]
group_by_spam = df.groupby(['subSpamWords', 'isSpam']).count().reset_index()
p1 = sns.barplot(data = group_by_spam, x='subSpamWords', y='isRe', hue='isSpam')
p1.set_title('Sub Spam Words vs Is Spam')
y_ticklabels = [f'{y:,.0f}' for y in p1.get_yticks()]
p1.set_yticklabels(y_ticklabels)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1,000'),
#  Text(0, 0, '2,000'),
#  Text(0, 0, '3,000'),
#  Text(0, 0, '4,000'),
#  Text(0, 0, '5,000'),
#  Text(0, 0, '6,000'),
#  Text(0, 0, '7,000'),
#  Text(0, 0, '8,000')]

# %% [markdown]
# ### Data Partioning

# %%
df = df.dropna() # TODO: Impute NAs, don't drop them

features = df[df.columns.difference(['isSpam'])]


X = pd.get_dummies(features, drop_first=True)
y = df['isSpam'].astype('object').apply(lambda x: 1 if x == 'T' else 0)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=7333)

# %% [markdown]
# ### Modeling - Decision Tree

# %%
clf = DecisionTreeClassifier(random_state=7333)
clf.fit(X_train, y_train)

pred = clf.predict(X_test)

# Accuracy
precision_score(y_test, pred)
# Out:
# 0.9386892177589852

# %%
clf.__dict__
# Out:
# {'criterion': 'gini',
#  'splitter': 'best',
#  'max_depth': None,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'min_weight_fraction_leaf': 0.0,
#  'max_features': None,
#  'random_state': 7333,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'class_weight': None,
#  'presort': 'deprecated',
#  'ccp_alpha': 0.0,
#  'n_features_': 51,
#  'n_outputs_': 1,
#  'classes_': array([0, 1]),
#  'n_classes_': 2,
#  'max_features_': 51,
#  'tree_': <sklearn.tree._tree.Tree at 0x7fda656ab3d8>}

# %% [markdown]
# ### Cross Validation
#
# 5-fold 80/20 stratified shuffle split

# %%
n_splits = 5
cv = StratifiedShuffleSplit(n_splits,test_size=.2, train_size=.8, random_state=7333)

# %% [markdown]
# ### Tuneable Parameters
#
# - SK to add color for each

# %%
criteria = ['gini', 'entropy'] # define possible splitting criteria
splitters = ['best', 'random'] 
max_depth = list(range(20, 50, 5))
min_samples_split = list(range(3, 5, 1))
min_samples_leaf = list(range(2, 5, 1))
max_features = ['auto', 'sqrt', 'log2']
random_state = 7333
max_leaf_nodes = list(range(5, 20, 3))
scoring = {
           # 'Accuracy':'accuracy'
           # , 'F-1 Score':'f1'
           # , 'AUC':'roc_auc'
             'Precision':'precision'
}

# %% [markdown]
# ### Model Tuning:
#
# General grid search:

# %%
pipe = Pipeline(steps=[('decision_tree', clf)])
clf_pipe = GridSearchCV(pipe
                   , cv=cv
                   ,param_grid = {
                                 'decision_tree__criterion':criteria,
                                 #'decision_tree__criterion':criteria,
                                 }
                   , verbose=True
                   , n_jobs=-1
                   , scoring=scoring
                   , refit='Precision'
                   , error_score=0.0)
clf_fit = clf_pipe.fit(X_train, y_train.values.ravel())
clf_predict = clf_fit.best_estimator_.predict(X_test)
print(f'Precision score of best estimator: {precision_score(y_test, clf_predict)}')
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:    0.2s remaining:    0.1s
# Precision score of best estimator: 0.9122448979591836
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.2s finished

# %%
clf_fit.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('decision_tree',
#                  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                         criterion='entropy', max_depth=None,
#                                         max_features=None, max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         presort='deprecated', random_state=7333,
#                                         splitter='best'))],
#          verbose=False)

# %%
results = pd.DataFrame(clf_fit.cv_results_)
scores = [col for col in results.columns if 'test_Precision' in col]
scores.append('params')
sorted_results = results[scores].sort_values(['rank_test_Precision']).T
print(sorted_results[1].params)
sorted_results
# Out:
# {'decision_tree__criterion': 'entropy'}
#                                                              1  \
# split0_test_Precision                                 0.916883
# split1_test_Precision                                 0.904762
# split2_test_Precision                                 0.951351
# split3_test_Precision                                 0.935135
# split4_test_Precision                                 0.933333
# mean_test_Precision                                   0.928293
# std_test_Precision                                   0.0160487
# rank_test_Precision                                          1
# params                 {'decision_tree__criterion': 'entropy'}
#
#                                                           0
# split0_test_Precision                              0.921409
# split1_test_Precision                              0.907162
# split2_test_Precision                              0.942779
# split3_test_Precision                              0.912234
# split4_test_Precision                              0.905852
# mean_test_Precision                                0.917887
# std_test_Precision                                 0.013593
# rank_test_Precision                                       2
# params                 {'decision_tree__criterion': 'gini'}

# %% [markdown]
# **Entropy** appears slightly better.... given that this precision is worse than baseline, we should continue our search and consider opting for **gini** if further tuning prefers it.

# %%
clf_pipe = GridSearchCV(pipe
                   , cv=cv
                   ,param_grid = {
                                 'decision_tree__criterion':criteria,
                                 'decision_tree__splitter':splitters,
                                 }
                   , verbose=True
                   , n_jobs=-1
                   , scoring=scoring
                   , refit='Precision'
                   , error_score=0.0)
clf_fit = clf_pipe.fit(X_train, y_train.values.ravel())
clf_predict = clf_fit.best_estimator_.predict(X_test)
print(f'Precision score of best estimator: {precision_score(y_test, clf_predict)}')
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Precision score of best estimator: 0.9122448979591836
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.3s finished

# %%
clf_fit.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('decision_tree',
#                  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                         criterion='entropy', max_depth=None,
#                                         max_features=None, max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         presort='deprecated', random_state=7333,
#                                         splitter='best'))],
#          verbose=False)

# %%
results = pd.DataFrame(clf_fit.cv_results_)
scores = [col for col in results.columns if 'test_Precision' in col]
scores.append('params')
sorted_results = results[scores].sort_values(['rank_test_Precision']).T
print(sorted_results[1].params)
sorted_results
# Out:
# {'decision_tree__criterion': 'gini', 'decision_tree__splitter': 'random'}
#                                                                        2  \
# split0_test_Precision                                           0.916883
# split1_test_Precision                                           0.904762
# split2_test_Precision                                           0.951351
# split3_test_Precision                                           0.935135
# split4_test_Precision                                           0.933333
# mean_test_Precision                                             0.928293
# std_test_Precision                                             0.0160487
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                        1  \
# split0_test_Precision                                           0.915789
# split1_test_Precision                                           0.893229
# split2_test_Precision                                           0.941341
# split3_test_Precision                                           0.941176
# split4_test_Precision                                           0.909561
# mean_test_Precision                                             0.920219
# std_test_Precision                                             0.0186923
# rank_test_Precision                                                    2
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                        3  \
# split0_test_Precision                                           0.905263
# split1_test_Precision                                            0.92328
# split2_test_Precision                                           0.921196
# split3_test_Precision                                           0.936111
# split4_test_Precision                                           0.909326
# mean_test_Precision                                             0.919035
# std_test_Precision                                             0.0109381
# rank_test_Precision                                                    3
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                        0
# split0_test_Precision                                           0.921409
# split1_test_Precision                                           0.907162
# split2_test_Precision                                           0.942779
# split3_test_Precision                                           0.912234
# split4_test_Precision                                           0.905852
# mean_test_Precision                                             0.917887
# std_test_Precision                                              0.013593
# rank_test_Precision                                                    4
# params                 {'decision_tree__criterion': 'gini', 'decision...

# %% [markdown]
# **gini** is preferred when split is **random**... explain?

# %%
clf_pipe = GridSearchCV(pipe
                   , cv=cv
                   ,param_grid = {
                                 'decision_tree__criterion':criteria,
                                 'decision_tree__splitter':splitters,
                                 'decision_tree__max_depth':max_depth,
                                 }
                   , verbose=True
                   , n_jobs=-1
                   , scoring=scoring
                   , refit='Precision'
                   , error_score=0.0)
clf_fit = clf_pipe.fit(X_train, y_train.values.ravel())
clf_predict = clf_fit.best_estimator_.predict(X_test)
print(f'Precision score of best estimator: {precision_score(y_test, clf_predict)}')
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.6s
# Precision score of best estimator: 0.9540481400437637
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    1.1s finished

# %%
clf_fit.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('decision_tree',
#                  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                         criterion='gini', max_depth=20,
#                                         max_features=None, max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         presort='deprecated', random_state=7333,
#                                         splitter='best'))],
#          verbose=False)

# %%
results = pd.DataFrame(clf_fit.cv_results_)
scores = [col for col in results.columns if 'test_Precision' in col]
scores.append('params')
sorted_results = results[scores].sort_values(['rank_test_Precision']).T
print(sorted_results[1].params)
sorted_results
# Out:
# {'decision_tree__criterion': 'gini', 'decision_tree__max_depth': 20, 'decision_tree__splitter': 'random'}
#                                                                       0   \
# split0_test_Precision                                           0.938028
# split1_test_Precision                                           0.930556
# split2_test_Precision                                           0.956647
# split3_test_Precision                                           0.945087
# split4_test_Precision                                           0.927614
# mean_test_Precision                                             0.939586
# std_test_Precision                                             0.0104753
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       1   \
# split0_test_Precision                                           0.934473
# split1_test_Precision                                           0.930168
# split2_test_Precision                                           0.951009
# split3_test_Precision                                           0.952522
# split4_test_Precision                                           0.926966
# mean_test_Precision                                             0.939028
# std_test_Precision                                             0.0106806
# rank_test_Precision                                                    2
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       12  \
# split0_test_Precision                                           0.919355
# split1_test_Precision                                           0.904639
# split2_test_Precision                                           0.945055
# split3_test_Precision                                           0.952646
# split4_test_Precision                                           0.939726
# mean_test_Precision                                             0.932284
# std_test_Precision                                              0.017689
# rank_test_Precision                                                    3
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       2   \
# split0_test_Precision                                           0.923288
# split1_test_Precision                                           0.920981
# split2_test_Precision                                           0.955182
# split3_test_Precision                                           0.936111
# split4_test_Precision                                           0.920844
# mean_test_Precision                                             0.931281
# std_test_Precision                                             0.0132174
# rank_test_Precision                                                    4
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       14  \
# split0_test_Precision                                           0.923077
# split1_test_Precision                                           0.895141
# split2_test_Precision                                           0.945946
# split3_test_Precision                                           0.950139
# split4_test_Precision                                           0.932796
# mean_test_Precision                                              0.92942
# std_test_Precision                                             0.0196421
# rank_test_Precision                                                    5
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       5   \
# split0_test_Precision                                           0.930108
# split1_test_Precision                                            0.92328
# split2_test_Precision                                            0.94302
# split3_test_Precision                                           0.935754
# split4_test_Precision                                           0.913613
# mean_test_Precision                                             0.929155
# std_test_Precision                                             0.0101269
# rank_test_Precision                                                    6
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       20  \
# split0_test_Precision                                           0.916883
# split1_test_Precision                                           0.904762
# split2_test_Precision                                           0.951351
# split3_test_Precision                                           0.935135
# split4_test_Precision                                           0.933333
# mean_test_Precision                                             0.928293
# std_test_Precision                                             0.0160487
# rank_test_Precision                                                    7
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       22  \
# split0_test_Precision                                           0.916883
# split1_test_Precision                                           0.904762
# split2_test_Precision                                           0.951351
# split3_test_Precision                                           0.935135
# split4_test_Precision                                           0.933333
# mean_test_Precision                                             0.928293
# std_test_Precision                                             0.0160487
# rank_test_Precision                                                    7
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       18  \
# split0_test_Precision                                           0.916883
# split1_test_Precision                                           0.904762
# split2_test_Precision                                           0.951351
# split3_test_Precision                                           0.935135
# split4_test_Precision                                           0.933333
# mean_test_Precision                                             0.928293
# std_test_Precision                                             0.0160487
# rank_test_Precision                                                    7
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       16  ...  \
# split0_test_Precision                                           0.915567  ...
# split1_test_Precision                                           0.904762  ...
# split2_test_Precision                                           0.950954  ...
# split3_test_Precision                                           0.935135  ...
# split4_test_Precision                                           0.930108  ...
# mean_test_Precision                                             0.927305  ...
# std_test_Precision                                             0.0159649  ...
# rank_test_Precision                                                   10  ...
# params                 {'decision_tree__criterion': 'entropy', 'decis...  ...
#
#                                                                       19  \
# split0_test_Precision                                           0.917772
# split1_test_Precision                                           0.908854
# split2_test_Precision                                           0.924324
# split3_test_Precision                                           0.936111
# split4_test_Precision                                           0.927224
# mean_test_Precision                                             0.922857
# std_test_Precision                                            0.00915238
# rank_test_Precision                                                   15
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       17  \
# split0_test_Precision                                           0.902703
# split1_test_Precision                                           0.918635
# split2_test_Precision                                           0.933884
# split3_test_Precision                                           0.932961
# split4_test_Precision                                           0.925729
# mean_test_Precision                                             0.922783
# std_test_Precision                                             0.0114537
# rank_test_Precision                                                   16
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       4   \
# split0_test_Precision                                           0.921409
# split1_test_Precision                                           0.916442
# split2_test_Precision                                           0.942623
# split3_test_Precision                                           0.922865
# split4_test_Precision                                           0.906494
# mean_test_Precision                                             0.921967
# std_test_Precision                                              0.011813
# rank_test_Precision                                                   17
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       11  \
# split0_test_Precision                                           0.915789
# split1_test_Precision                                           0.893229
# split2_test_Precision                                           0.941341
# split3_test_Precision                                           0.941176
# split4_test_Precision                                           0.909561
# mean_test_Precision                                             0.920219
# std_test_Precision                                             0.0186923
# rank_test_Precision                                                   18
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       21  \
# split0_test_Precision                                           0.917808
# split1_test_Precision                                           0.905263
# split2_test_Precision                                           0.921196
# split3_test_Precision                                           0.936111
# split4_test_Precision                                           0.909326
# mean_test_Precision                                             0.917941
# std_test_Precision                                             0.0107303
# rank_test_Precision                                                   19
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       10  \
# split0_test_Precision                                           0.921409
# split1_test_Precision                                           0.907162
# split2_test_Precision                                           0.942779
# split3_test_Precision                                           0.912234
# split4_test_Precision                                           0.905852
# mean_test_Precision                                             0.917887
# std_test_Precision                                              0.013593
# rank_test_Precision                                                   20
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       8   \
# split0_test_Precision                                           0.921409
# split1_test_Precision                                           0.907162
# split2_test_Precision                                           0.942779
# split3_test_Precision                                           0.912234
# split4_test_Precision                                           0.905852
# mean_test_Precision                                             0.917887
# std_test_Precision                                              0.013593
# rank_test_Precision                                                   20
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       6   \
# split0_test_Precision                                           0.921409
# split1_test_Precision                                           0.907162
# split2_test_Precision                                           0.942779
# split3_test_Precision                                           0.912234
# split4_test_Precision                                           0.905852
# mean_test_Precision                                             0.917887
# std_test_Precision                                              0.013593
# rank_test_Precision                                                   20
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       13  \
# split0_test_Precision                                           0.920765
# split1_test_Precision                                           0.896373
# split2_test_Precision                                           0.931624
# split3_test_Precision                                           0.934911
# split4_test_Precision                                           0.894872
# mean_test_Precision                                             0.915709
# std_test_Precision                                             0.0170625
# rank_test_Precision                                                   23
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       23
# split0_test_Precision                                           0.905263
# split1_test_Precision                                           0.885204
# split2_test_Precision                                           0.921196
# split3_test_Precision                                           0.936111
# split4_test_Precision                                           0.909326
# mean_test_Precision                                              0.91142
# std_test_Precision                                             0.0169398
# rank_test_Precision                                                   24
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
# [9 rows x 24 columns]

# %% [markdown]
# Setting max_depth = 20 seems to have a sizeable improvement on Precision, let's keep that in mind.

# %%
clf_pipe = GridSearchCV(pipe
                   , cv=cv
                   ,param_grid = {
                                 'decision_tree__criterion':criteria,
                                 'decision_tree__splitter':splitters,
                                 'decision_tree__max_depth':max_depth,
                                 'decision_tree__min_samples_split': min_samples_split
                                 }
                   , verbose=True
                   , n_jobs=-1
                   , scoring=scoring
                   , refit='Precision'
                   , error_score=0.0)
clf_fit = clf_pipe.fit(X_train, y_train.values.ravel())
clf_predict = clf_fit.best_estimator_.predict(X_test)
print(f'Precision score of best estimator: {precision_score(y_test, clf_predict)}')
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.7s
# Precision score of best estimator: 0.9518599562363238
# [Parallel(n_jobs=-1)]: Done 240 out of 240 | elapsed:    2.0s finished

# %%
clf_fit.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('decision_tree',
#                  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                         criterion='gini', max_depth=20,
#                                         max_features=None, max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=3,
#                                         min_weight_fraction_leaf=0.0,
#                                         presort='deprecated', random_state=7333,
#                                         splitter='best'))],
#          verbose=False)

# %%
results = pd.DataFrame(clf_fit.cv_results_)
scores = [col for col in results.columns if 'test_Precision' in col]
scores.append('params')
sorted_results = results[scores].sort_values(['rank_test_Precision']).T
print(sorted_results[1].params)
sorted_results
# Out:
# {'decision_tree__criterion': 'gini', 'decision_tree__max_depth': 20, 'decision_tree__min_samples_split': 3, 'decision_tree__splitter': 'random'}
#                                                                       0   \
# split0_test_Precision                                           0.937677
# split1_test_Precision                                           0.938028
# split2_test_Precision                                           0.962428
# split3_test_Precision                                           0.942197
# split4_test_Precision                                           0.931694
# mean_test_Precision                                             0.942405
# std_test_Precision                                             0.0105564
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       9   \
# split0_test_Precision                                           0.951289
# split1_test_Precision                                           0.907162
# split2_test_Precision                                           0.946479
# split3_test_Precision                                           0.958333
# split4_test_Precision                                           0.937158
# mean_test_Precision                                             0.940084
# std_test_Precision                                             0.0178433
# rank_test_Precision                                                    2
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       1   \
# split0_test_Precision                                           0.940678
# split1_test_Precision                                            0.92011
# split2_test_Precision                                           0.948424
# split3_test_Precision                                           0.947977
# split4_test_Precision                                            0.94302
# mean_test_Precision                                             0.940042
# std_test_Precision                                             0.0103901
# rank_test_Precision                                                    3
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       21  \
# split0_test_Precision                                           0.941989
# split1_test_Precision                                           0.921196
# split2_test_Precision                                           0.930481
# split3_test_Precision                                            0.94382
# split4_test_Precision                                            0.95082
# mean_test_Precision                                             0.937661
# std_test_Precision                                             0.0105116
# rank_test_Precision                                                    4
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       29  \
# split0_test_Precision                                           0.921127
# split1_test_Precision                                           0.936986
# split2_test_Precision                                           0.940845
# split3_test_Precision                                           0.933884
# split4_test_Precision                                           0.954416
# mean_test_Precision                                             0.937452
# std_test_Precision                                             0.0107587
# rank_test_Precision                                                    5
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       2   \
# split0_test_Precision                                           0.935028
# split1_test_Precision                                           0.925414
# split2_test_Precision                                           0.956772
# split3_test_Precision                                           0.944444
# split4_test_Precision                                           0.916442
# mean_test_Precision                                              0.93562
# std_test_Precision                                             0.0141251
# rank_test_Precision                                                    6
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       17  \
# split0_test_Precision                                           0.929919
# split1_test_Precision                                           0.918206
# split2_test_Precision                                           0.929972
# split3_test_Precision                                            0.94382
# split4_test_Precision                                            0.95082
# mean_test_Precision                                             0.934547
# std_test_Precision                                             0.0114906
# rank_test_Precision                                                    7
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       13  \
# split0_test_Precision                                           0.937669
# split1_test_Precision                                           0.917772
# split2_test_Precision                                           0.954802
# split3_test_Precision                                           0.924791
# split4_test_Precision                                            0.93531
# mean_test_Precision                                             0.934069
# std_test_Precision                                             0.0126178
# rank_test_Precision                                                    8
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       3   \
# split0_test_Precision                                           0.926136
# split1_test_Precision                                           0.921348
# split2_test_Precision                                           0.941349
# split3_test_Precision                                           0.951807
# split4_test_Precision                                           0.927978
# mean_test_Precision                                             0.933724
# std_test_Precision                                             0.0112151
# rank_test_Precision                                                    9
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       26  ...  \
# split0_test_Precision                                           0.921833  ...
# split1_test_Precision                                           0.903394  ...
# split2_test_Precision                                           0.944134  ...
# split3_test_Precision                                            0.94958  ...
# split4_test_Precision                                            0.93733  ...
# mean_test_Precision                                             0.931254  ...
# std_test_Precision                                             0.0167545  ...
# rank_test_Precision                                                   10  ...
# params                 {'decision_tree__criterion': 'entropy', 'decis...  ...
#
#                                                                       22  \
# split0_test_Precision                                           0.915761
# split1_test_Precision                                           0.909333
# split2_test_Precision                                           0.934247
# split3_test_Precision                                           0.922865
# split4_test_Precision                                           0.913158
# mean_test_Precision                                             0.919073
# std_test_Precision                                            0.00877994
# rank_test_Precision                                                   39
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       18  \
# split0_test_Precision                                           0.915761
# split1_test_Precision                                           0.909333
# split2_test_Precision                                           0.934247
# split3_test_Precision                                           0.922865
# split4_test_Precision                                           0.913158
# mean_test_Precision                                             0.919073
# std_test_Precision                                            0.00877994
# rank_test_Precision                                                   39
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       14  \
# split0_test_Precision                                           0.915761
# split1_test_Precision                                           0.909333
# split2_test_Precision                                           0.934247
# split3_test_Precision                                           0.922865
# split4_test_Precision                                           0.913158
# mean_test_Precision                                             0.919073
# std_test_Precision                                            0.00877994
# rank_test_Precision                                                   39
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                       41  \
# split0_test_Precision                                           0.916216
# split1_test_Precision                                           0.923706
# split2_test_Precision                                           0.927614
# split3_test_Precision                                            0.90566
# split4_test_Precision                                           0.915789
# mean_test_Precision                                             0.917797
# std_test_Precision                                            0.00755132
# rank_test_Precision                                                   42
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       47  \
# split0_test_Precision                                           0.918033
# split1_test_Precision                                           0.916667
# split2_test_Precision                                           0.914667
# split3_test_Precision                                           0.917808
# split4_test_Precision                                           0.917553
# mean_test_Precision                                             0.916946
# std_test_Precision                                            0.00123017
# rank_test_Precision                                                   43
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       39  \
# split0_test_Precision                                           0.914601
# split1_test_Precision                                           0.915567
# split2_test_Precision                                            0.93733
# split3_test_Precision                                           0.922865
# split4_test_Precision                                           0.893229
# mean_test_Precision                                             0.916718
# std_test_Precision                                              0.014284
# rank_test_Precision                                                   44
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       43  \
# split0_test_Precision                                           0.910326
# split1_test_Precision                                           0.918919
# split2_test_Precision                                           0.916667
# split3_test_Precision                                           0.917808
# split4_test_Precision                                           0.917553
# mean_test_Precision                                             0.916255
# std_test_Precision                                            0.00305011
# rank_test_Precision                                                   45
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       45  \
# split0_test_Precision                                           0.914209
# split1_test_Precision                                           0.917989
# split2_test_Precision                                           0.927614
# split3_test_Precision                                            0.90566
# split4_test_Precision                                           0.915789
# mean_test_Precision                                             0.916252
# std_test_Precision                                            0.00705241
# rank_test_Precision                                                   46
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       37  \
# split0_test_Precision                                           0.903485
# split1_test_Precision                                           0.904762
# split2_test_Precision                                           0.938172
# split3_test_Precision                                            0.90566
# split4_test_Precision                                            0.92126
# mean_test_Precision                                             0.914668
# std_test_Precision                                              0.013418
# rank_test_Precision                                                   47
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                       27
# split0_test_Precision                                           0.909605
# split1_test_Precision                                           0.887399
# split2_test_Precision                                           0.919771
# split3_test_Precision                                            0.90411
# split4_test_Precision                                           0.930168
# mean_test_Precision                                              0.91021
# std_test_Precision                                             0.0144749
# rank_test_Precision                                                   48
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
# [9 rows x 48 columns]

# %% [markdown]
# **min_samples_split** seems to best at the lowest possible value: explanantion?

# %%
clf_pipe = GridSearchCV(pipe
                   , cv=cv
                   ,param_grid = {
                                 'decision_tree__criterion':criteria,
                                 'decision_tree__splitter':splitters,
                                 'decision_tree__max_depth':max_depth,
                                 'decision_tree__min_samples_split': min_samples_split,
                                 'decision_tree__min_samples_leaf': min_samples_leaf,
                                 }
                   , verbose=True
                   , n_jobs=-1
                   , scoring=scoring
                   , refit='Precision'
                   , error_score=0.0)
clf_fit = clf_pipe.fit(X_train, y_train.values.ravel())
clf_predict = clf_fit.best_estimator_.predict(X_test)
print(f'Precision score of best estimator: {precision_score(y_test, clf_predict)}')
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 352 tasks      | elapsed:    3.7s
# Precision score of best estimator: 0.9309576837416481
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:    6.5s finished

# %%
clf_fit.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('decision_tree',
#                  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                         criterion='gini', max_depth=20,
#                                         max_features=None, max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=2, min_samples_split=3,
#                                         min_weight_fraction_leaf=0.0,
#                                         presort='deprecated', random_state=7333,
#                                         splitter='random'))],
#          verbose=False)

# %%
results = pd.DataFrame(clf_fit.cv_results_)
scores = [col for col in results.columns if 'test_Precision' in col]
scores.append('params')
sorted_results = results[scores].sort_values(['rank_test_Precision']).T
print(sorted_results[1].params)
sorted_results
# Out:
# {'decision_tree__criterion': 'gini', 'decision_tree__max_depth': 20, 'decision_tree__min_samples_leaf': 2, 'decision_tree__min_samples_split': 3, 'decision_tree__splitter': 'random'}
#                                                                      1    \
# split0_test_Precision                                           0.937143
# split1_test_Precision                                           0.945402
# split2_test_Precision                                           0.942363
# split3_test_Precision                                               0.96
# split4_test_Precision                                           0.931818
# mean_test_Precision                                             0.943345
# std_test_Precision                                            0.00952806
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      3    \
# split0_test_Precision                                           0.937143
# split1_test_Precision                                           0.945402
# split2_test_Precision                                           0.942363
# split3_test_Precision                                               0.96
# split4_test_Precision                                           0.931818
# mean_test_Precision                                             0.943345
# std_test_Precision                                            0.00952806
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      0    \
# split0_test_Precision                                           0.936599
# split1_test_Precision                                            0.94051
# split2_test_Precision                                            0.95858
# split3_test_Precision                                           0.944606
# split4_test_Precision                                           0.918033
# mean_test_Precision                                             0.939666
# std_test_Precision                                             0.0131168
# rank_test_Precision                                                    3
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      2    \
# split0_test_Precision                                           0.936599
# split1_test_Precision                                            0.94051
# split2_test_Precision                                            0.95858
# split3_test_Precision                                           0.944606
# split4_test_Precision                                           0.918033
# mean_test_Precision                                             0.939666
# std_test_Precision                                             0.0131168
# rank_test_Precision                                                    3
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      15   \
# split0_test_Precision                                           0.929972
# split1_test_Precision                                           0.922636
# split2_test_Precision                                           0.949102
# split3_test_Precision                                           0.957447
# split4_test_Precision                                           0.919668
# mean_test_Precision                                             0.935765
# std_test_Precision                                             0.0149199
# rank_test_Precision                                                    5
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      13   \
# split0_test_Precision                                           0.929972
# split1_test_Precision                                           0.922636
# split2_test_Precision                                           0.949102
# split3_test_Precision                                           0.957447
# split4_test_Precision                                           0.919668
# mean_test_Precision                                             0.935765
# std_test_Precision                                             0.0149199
# rank_test_Precision                                                    5
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      74   \
# split0_test_Precision                                           0.918033
# split1_test_Precision                                           0.915567
# split2_test_Precision                                           0.946176
# split3_test_Precision                                           0.943662
# split4_test_Precision                                           0.943662
# mean_test_Precision                                              0.93342
# std_test_Precision                                             0.0136234
# rank_test_Precision                                                    7
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      72   \
# split0_test_Precision                                           0.918033
# split1_test_Precision                                           0.915567
# split2_test_Precision                                           0.946176
# split3_test_Precision                                           0.943662
# split4_test_Precision                                           0.943662
# mean_test_Precision                                              0.93342
# std_test_Precision                                             0.0136234
# rank_test_Precision                                                    7
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      51   \
# split0_test_Precision                                           0.928177
# split1_test_Precision                                           0.928775
# split2_test_Precision                                           0.948171
# split3_test_Precision                                           0.926136
# split4_test_Precision                                           0.928571
# mean_test_Precision                                             0.931966
# std_test_Precision                                             0.0081565
# rank_test_Precision                                                    9
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      49   ...  \
# split0_test_Precision                                           0.928177  ...
# split1_test_Precision                                           0.928775  ...
# split2_test_Precision                                           0.948171  ...
# split3_test_Precision                                           0.926136  ...
# split4_test_Precision                                           0.928571  ...
# mean_test_Precision                                             0.931966  ...
# std_test_Precision                                             0.0081565  ...
# rank_test_Precision                                                    9  ...
# params                 {'decision_tree__criterion': 'gini', 'decision...  ...
#
#                                                                      125  \
# split0_test_Precision                                           0.904632
# split1_test_Precision                                           0.875325
# split2_test_Precision                                              0.888
# split3_test_Precision                                           0.888889
# split4_test_Precision                                           0.884021
# mean_test_Precision                                             0.888173
# std_test_Precision                                            0.00952647
# rank_test_Precision                                                  135
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      127  \
# split0_test_Precision                                           0.904632
# split1_test_Precision                                           0.875325
# split2_test_Precision                                              0.888
# split3_test_Precision                                           0.888889
# split4_test_Precision                                           0.884021
# mean_test_Precision                                             0.888173
# std_test_Precision                                            0.00952647
# rank_test_Precision                                                  135
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      139  \
# split0_test_Precision                                           0.904632
# split1_test_Precision                                           0.870647
# split2_test_Precision                                              0.888
# split3_test_Precision                                           0.888889
# split4_test_Precision                                           0.877238
# mean_test_Precision                                             0.885881
# std_test_Precision                                             0.0115925
# rank_test_Precision                                                  137
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      137  \
# split0_test_Precision                                           0.904632
# split1_test_Precision                                           0.870647
# split2_test_Precision                                              0.888
# split3_test_Precision                                           0.888889
# split4_test_Precision                                           0.877238
# mean_test_Precision                                             0.885881
# std_test_Precision                                             0.0115925
# rank_test_Precision                                                  137
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      119  \
# split0_test_Precision                                           0.889503
# split1_test_Precision                                           0.893506
# split2_test_Precision                                              0.875
# split3_test_Precision                                           0.880223
# split4_test_Precision                                           0.887363
# mean_test_Precision                                             0.885119
# std_test_Precision                                            0.00664782
# rank_test_Precision                                                  139
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      117  \
# split0_test_Precision                                           0.889503
# split1_test_Precision                                           0.893506
# split2_test_Precision                                              0.875
# split3_test_Precision                                           0.880223
# split4_test_Precision                                           0.887363
# mean_test_Precision                                             0.885119
# std_test_Precision                                            0.00664782
# rank_test_Precision                                                  139
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      141  \
# split0_test_Precision                                           0.870712
# split1_test_Precision                                           0.893506
# split2_test_Precision                                              0.875
# split3_test_Precision                                           0.880223
# split4_test_Precision                                           0.887363
# mean_test_Precision                                             0.881361
# std_test_Precision                                            0.00823023
# rank_test_Precision                                                  141
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      129  \
# split0_test_Precision                                           0.870712
# split1_test_Precision                                           0.893506
# split2_test_Precision                                              0.875
# split3_test_Precision                                           0.880223
# split4_test_Precision                                           0.887363
# mean_test_Precision                                             0.881361
# std_test_Precision                                            0.00823023
# rank_test_Precision                                                  141
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      131  \
# split0_test_Precision                                           0.870712
# split1_test_Precision                                           0.893506
# split2_test_Precision                                              0.875
# split3_test_Precision                                           0.880223
# split4_test_Precision                                           0.887363
# mean_test_Precision                                             0.881361
# std_test_Precision                                            0.00823023
# rank_test_Precision                                                  141
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      143
# split0_test_Precision                                           0.870712
# split1_test_Precision                                           0.893506
# split2_test_Precision                                              0.875
# split3_test_Precision                                           0.880223
# split4_test_Precision                                           0.887363
# mean_test_Precision                                             0.881361
# std_test_Precision                                            0.00823023
# rank_test_Precision                                                  141
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
# [9 rows x 144 columns]

# %% [markdown]
# Tuning min_samples leaf made things worse....

# %%
clf_pipe = GridSearchCV(pipe
                   , cv=cv
                   ,param_grid = {
                                 'decision_tree__criterion':criteria,
                                 'decision_tree__splitter':splitters,
                                 'decision_tree__max_depth':max_depth,
                                 'decision_tree__min_samples_split': min_samples_split,
                                 'decision_tree__min_samples_leaf': min_samples_leaf,
                                 'decision_tree__max_features': max_features
                                 }
                   , verbose=True
                   , n_jobs=-1
                   , scoring=scoring
                   , refit='Precision'
                   , error_score=0.0)
clf_fit = clf_pipe.fit(X_train, y_train.values.ravel())
clf_predict = clf_fit.best_estimator_.predict(X_test)
print(f'Precision score of best estimator: {precision_score(y_test, clf_predict)}')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 1200 tasks      | elapsed:    4.7s
# Precision score of best estimator: 0.9151376146788991
# [Parallel(n_jobs=-1)]: Done 2160 out of 2160 | elapsed:    7.7s finished

# %%
clf_fit.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('decision_tree',
#                  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                         criterion='gini', max_depth=20,
#                                         max_features='auto',
#                                         max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=2, min_samples_split=3,
#                                         min_weight_fraction_leaf=0.0,
#                                         presort='deprecated', random_state=7333,
#                                         splitter='best'))],
#          verbose=False)

# %%
results = pd.DataFrame(clf_fit.cv_results_)
scores = [col for col in results.columns if 'test_Precision' in col]
scores.append('params')
sorted_results = results[scores].sort_values(['rank_test_Precision']).T
print(sorted_results[1].params)
sorted_results
# Out:
# {'decision_tree__criterion': 'gini', 'decision_tree__max_depth': 20, 'decision_tree__max_features': 'auto', 'decision_tree__min_samples_leaf': 2, 'decision_tree__min_samples_split': 3, 'decision_tree__splitter': 'random'}
#                                                                      0    \
# split0_test_Precision                                            0.92515
# split1_test_Precision                                           0.927978
# split2_test_Precision                                           0.932153
# split3_test_Precision                                           0.915205
# split4_test_Precision                                           0.894737
# mean_test_Precision                                             0.919044
# std_test_Precision                                             0.0133756
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      2    \
# split0_test_Precision                                            0.92515
# split1_test_Precision                                           0.927978
# split2_test_Precision                                           0.932153
# split3_test_Precision                                           0.915205
# split4_test_Precision                                           0.894737
# mean_test_Precision                                             0.919044
# std_test_Precision                                             0.0133756
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      14   \
# split0_test_Precision                                            0.92515
# split1_test_Precision                                           0.927978
# split2_test_Precision                                           0.932153
# split3_test_Precision                                           0.915205
# split4_test_Precision                                           0.894737
# mean_test_Precision                                             0.919044
# std_test_Precision                                             0.0133756
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      12   \
# split0_test_Precision                                            0.92515
# split1_test_Precision                                           0.927978
# split2_test_Precision                                           0.932153
# split3_test_Precision                                           0.915205
# split4_test_Precision                                           0.894737
# mean_test_Precision                                             0.919044
# std_test_Precision                                             0.0133756
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      266  \
# split0_test_Precision                                           0.908333
# split1_test_Precision                                           0.919137
# split2_test_Precision                                            0.93787
# split3_test_Precision                                           0.919308
# split4_test_Precision                                           0.895317
# mean_test_Precision                                             0.915993
# std_test_Precision                                             0.0140403
# rank_test_Precision                                                    5
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      264  \
# split0_test_Precision                                           0.908333
# split1_test_Precision                                           0.919137
# split2_test_Precision                                            0.93787
# split3_test_Precision                                           0.919308
# split4_test_Precision                                           0.895317
# mean_test_Precision                                             0.915993
# std_test_Precision                                             0.0140403
# rank_test_Precision                                                    5
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      254  \
# split0_test_Precision                                           0.908333
# split1_test_Precision                                           0.919137
# split2_test_Precision                                            0.93787
# split3_test_Precision                                           0.919308
# split4_test_Precision                                           0.895317
# mean_test_Precision                                             0.915993
# std_test_Precision                                             0.0140403
# rank_test_Precision                                                    5
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      252  \
# split0_test_Precision                                           0.908333
# split1_test_Precision                                           0.919137
# split2_test_Precision                                            0.93787
# split3_test_Precision                                           0.919308
# split4_test_Precision                                           0.895317
# mean_test_Precision                                             0.915993
# std_test_Precision                                             0.0140403
# rank_test_Precision                                                    5
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      278  \
# split0_test_Precision                                            0.90678
# split1_test_Precision                                           0.916667
# split2_test_Precision                                           0.925501
# split3_test_Precision                                           0.915916
# split4_test_Precision                                                0.9
# mean_test_Precision                                             0.912973
# std_test_Precision                                            0.00878546
# rank_test_Precision                                                    9
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      276  ...  \
# split0_test_Precision                                            0.90678  ...
# split1_test_Precision                                           0.916667  ...
# split2_test_Precision                                           0.925501  ...
# split3_test_Precision                                           0.915916  ...
# split4_test_Precision                                                0.9  ...
# mean_test_Precision                                             0.912973  ...
# std_test_Precision                                            0.00878546  ...
# rank_test_Precision                                                    9  ...
# params                 {'decision_tree__criterion': 'entropy', 'decis...  ...
#
#                                                                      117  \
# split0_test_Precision                                           0.812332
# split1_test_Precision                                            0.88724
# split2_test_Precision                                           0.822674
# split3_test_Precision                                           0.869301
# split4_test_Precision                                            0.84359
# mean_test_Precision                                             0.847028
# std_test_Precision                                             0.0280065
# rank_test_Precision                                                  423
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      119  \
# split0_test_Precision                                           0.812332
# split1_test_Precision                                            0.88724
# split2_test_Precision                                           0.822674
# split3_test_Precision                                           0.869301
# split4_test_Precision                                            0.84359
# mean_test_Precision                                             0.847028
# std_test_Precision                                             0.0280065
# rank_test_Precision                                                  423
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      129  \
# split0_test_Precision                                           0.812332
# split1_test_Precision                                            0.88724
# split2_test_Precision                                           0.822674
# split3_test_Precision                                           0.869301
# split4_test_Precision                                            0.84359
# mean_test_Precision                                             0.847028
# std_test_Precision                                             0.0280065
# rank_test_Precision                                                  423
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      131  \
# split0_test_Precision                                           0.812332
# split1_test_Precision                                            0.88724
# split2_test_Precision                                           0.822674
# split3_test_Precision                                           0.869301
# split4_test_Precision                                            0.84359
# mean_test_Precision                                             0.847028
# std_test_Precision                                             0.0280065
# rank_test_Precision                                                  423
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      35   \
# split0_test_Precision                                           0.755611
# split1_test_Precision                                           0.871429
# split2_test_Precision                                           0.894389
# split3_test_Precision                                           0.918149
# split4_test_Precision                                           0.789598
# mean_test_Precision                                             0.845835
# std_test_Precision                                             0.0625219
# rank_test_Precision                                                  427
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      33   \
# split0_test_Precision                                           0.755611
# split1_test_Precision                                           0.871429
# split2_test_Precision                                           0.894389
# split3_test_Precision                                           0.918149
# split4_test_Precision                                           0.789598
# mean_test_Precision                                             0.845835
# std_test_Precision                                             0.0625219
# rank_test_Precision                                                  427
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                      273  \
# split0_test_Precision                                            0.84438
# split1_test_Precision                                           0.867403
# split2_test_Precision                                           0.814917
# split3_test_Precision                                           0.835509
# split4_test_Precision                                            0.85989
# mean_test_Precision                                              0.84442
# std_test_Precision                                             0.0185331
# rank_test_Precision                                                  429
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      263  \
# split0_test_Precision                                            0.84438
# split1_test_Precision                                           0.867403
# split2_test_Precision                                           0.814917
# split3_test_Precision                                           0.835509
# split4_test_Precision                                            0.85989
# mean_test_Precision                                              0.84442
# std_test_Precision                                             0.0185331
# rank_test_Precision                                                  429
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      261  \
# split0_test_Precision                                            0.84438
# split1_test_Precision                                           0.867403
# split2_test_Precision                                           0.814917
# split3_test_Precision                                           0.835509
# split4_test_Precision                                            0.85989
# mean_test_Precision                                              0.84442
# std_test_Precision                                             0.0185331
# rank_test_Precision                                                  429
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                      275
# split0_test_Precision                                            0.84438
# split1_test_Precision                                           0.867403
# split2_test_Precision                                           0.814917
# split3_test_Precision                                           0.835509
# split4_test_Precision                                            0.85989
# mean_test_Precision                                              0.84442
# std_test_Precision                                             0.0185331
# rank_test_Precision                                                  429
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
# [9 rows x 432 columns]

# %% [markdown]
# Tuning **max_features** gave best outcome so far.

# %%
clf_pipe = GridSearchCV(pipe
                   , cv=cv
                   ,param_grid = {
                                 'decision_tree__criterion':criteria,
                                 'decision_tree__splitter':splitters,
                                 'decision_tree__max_depth':max_depth,
                                 'decision_tree__min_samples_split': min_samples_split,
                                 'decision_tree__min_samples_leaf': min_samples_leaf,
                                 'decision_tree__max_features': max_features,
                                 'decision_tree__max_leaf_nodes': max_leaf_nodes,
                                 }
                   , verbose=True
                   , n_jobs=-1
                   , scoring=scoring
                   , refit='Precision'
                   , error_score=0.0)
clf_fit = clf_pipe.fit(X_train, y_train.values.ravel())
clf_predict = clf_fit.best_estimator_.predict(X_test)
print(f'Precision score of best estimator: {precision_score(y_test, clf_predict)}')
# Out:
# Fitting 5 folds for each of 2160 candidates, totalling 10800 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 2160 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 6160 tasks      | elapsed:   16.2s
# Precision score of best estimator: 0.985
# [Parallel(n_jobs=-1)]: Done 10800 out of 10800 | elapsed:   29.4s finished

# %%
clf_fit.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('decision_tree',
#                  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                         criterion='entropy', max_depth=20,
#                                         max_features='log2', max_leaf_nodes=8,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=3, min_samples_split=3,
#                                         min_weight_fraction_leaf=0.0,
#                                         presort='deprecated', random_state=7333,
#                                         splitter='random'))],
#          verbose=False)

# %%
results = pd.DataFrame(clf_fit.cv_results_)
scores = [col for col in results.columns if 'test_Precision' in col]
scores.append('params')
sorted_results = results[scores].sort_values(['rank_test_Precision']).T
print(sorted_results[1].params)
sorted_results
# Out:
# {'decision_tree__criterion': 'gini', 'decision_tree__max_depth': 20, 'decision_tree__max_features': 'auto', 'decision_tree__max_leaf_nodes': 5, 'decision_tree__min_samples_leaf': 2, 'decision_tree__min_samples_split': 3, 'decision_tree__splitter': 'random'}
#                                                                     2123  \
# split0_test_Precision                                           0.987097
# split1_test_Precision                                                  1
# split2_test_Precision                                           0.992908
# split3_test_Precision                                           0.980132
# split4_test_Precision                                           0.993197
# mean_test_Precision                                             0.990667
# std_test_Precision                                            0.00666711
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                     1763  \
# split0_test_Precision                                           0.987097
# split1_test_Precision                                                  1
# split2_test_Precision                                           0.992908
# split3_test_Precision                                           0.980132
# split4_test_Precision                                           0.993197
# mean_test_Precision                                             0.990667
# std_test_Precision                                            0.00666711
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                     1757  \
# split0_test_Precision                                           0.987097
# split1_test_Precision                                                  1
# split2_test_Precision                                           0.992908
# split3_test_Precision                                           0.980132
# split4_test_Precision                                           0.993197
# mean_test_Precision                                             0.990667
# std_test_Precision                                            0.00666711
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                     1397  \
# split0_test_Precision                                           0.987097
# split1_test_Precision                                                  1
# split2_test_Precision                                           0.992908
# split3_test_Precision                                           0.980132
# split4_test_Precision                                           0.993197
# mean_test_Precision                                             0.990667
# std_test_Precision                                            0.00666711
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                     1399  \
# split0_test_Precision                                           0.987097
# split1_test_Precision                                                  1
# split2_test_Precision                                           0.992908
# split3_test_Precision                                           0.980132
# split4_test_Precision                                           0.993197
# mean_test_Precision                                             0.990667
# std_test_Precision                                            0.00666711
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                     1943  \
# split0_test_Precision                                           0.987097
# split1_test_Precision                                                  1
# split2_test_Precision                                           0.992908
# split3_test_Precision                                           0.980132
# split4_test_Precision                                           0.993197
# mean_test_Precision                                             0.990667
# std_test_Precision                                            0.00666711
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                     1941  \
# split0_test_Precision                                           0.987097
# split1_test_Precision                                                  1
# split2_test_Precision                                           0.992908
# split3_test_Precision                                           0.980132
# split4_test_Precision                                           0.993197
# mean_test_Precision                                             0.990667
# std_test_Precision                                            0.00666711
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                     1939  \
# split0_test_Precision                                           0.987097
# split1_test_Precision                                                  1
# split2_test_Precision                                           0.992908
# split3_test_Precision                                           0.980132
# split4_test_Precision                                           0.993197
# mean_test_Precision                                             0.990667
# std_test_Precision                                            0.00666711
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                     1223  \
# split0_test_Precision                                           0.987097
# split1_test_Precision                                                  1
# split2_test_Precision                                           0.992908
# split3_test_Precision                                           0.980132
# split4_test_Precision                                           0.993197
# mean_test_Precision                                             0.990667
# std_test_Precision                                            0.00666711
# rank_test_Precision                                                    1
# params                 {'decision_tree__criterion': 'entropy', 'decis...
#
#                                                                     2117  ...  \
# split0_test_Precision                                           0.987097  ...
# split1_test_Precision                                                  1  ...
# split2_test_Precision                                           0.992908  ...
# split3_test_Precision                                           0.980132  ...
# split4_test_Precision                                           0.993197  ...
# mean_test_Precision                                             0.990667  ...
# std_test_Precision                                            0.00666711  ...
# rank_test_Precision                                                    1  ...
# params                 {'decision_tree__criterion': 'entropy', 'decis...  ...
#
#                                                                     749   \
# split0_test_Precision                                           0.728125
# split1_test_Precision                                           0.634694
# split2_test_Precision                                            0.62963
# split3_test_Precision                                           0.621032
# split4_test_Precision                                           0.724919
# mean_test_Precision                                              0.66768
# std_test_Precision                                             0.0482533
# rank_test_Precision                                                 2089
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                     29    \
# split0_test_Precision                                           0.728125
# split1_test_Precision                                           0.634694
# split2_test_Precision                                            0.62963
# split3_test_Precision                                           0.621032
# split4_test_Precision                                           0.724919
# mean_test_Precision                                              0.66768
# std_test_Precision                                             0.0482533
# rank_test_Precision                                                 2089
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                     751   \
# split0_test_Precision                                           0.728125
# split1_test_Precision                                           0.634694
# split2_test_Precision                                            0.62963
# split3_test_Precision                                           0.621032
# split4_test_Precision                                           0.724919
# mean_test_Precision                                              0.66768
# std_test_Precision                                             0.0482533
# rank_test_Precision                                                 2089
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                     815   \
# split0_test_Precision                                           0.728125
# split1_test_Precision                                           0.634694
# split2_test_Precision                                            0.62963
# split3_test_Precision                                           0.621032
# split4_test_Precision                                           0.724919
# mean_test_Precision                                              0.66768
# std_test_Precision                                             0.0482533
# rank_test_Precision                                                 2089
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                     27    \
# split0_test_Precision                                           0.728125
# split1_test_Precision                                           0.634694
# split2_test_Precision                                            0.62963
# split3_test_Precision                                           0.621032
# split4_test_Precision                                           0.724919
# mean_test_Precision                                              0.66768
# std_test_Precision                                             0.0482533
# rank_test_Precision                                                 2089
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                     753   \
# split0_test_Precision                                           0.728125
# split1_test_Precision                                           0.634694
# split2_test_Precision                                            0.62963
# split3_test_Precision                                           0.621032
# split4_test_Precision                                           0.724919
# mean_test_Precision                                              0.66768
# std_test_Precision                                             0.0482533
# rank_test_Precision                                                 2089
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                     453   \
# split0_test_Precision                                           0.728125
# split1_test_Precision                                           0.634694
# split2_test_Precision                                            0.62963
# split3_test_Precision                                           0.621032
# split4_test_Precision                                           0.724919
# mean_test_Precision                                              0.66768
# std_test_Precision                                             0.0482533
# rank_test_Precision                                                 2089
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                     985   \
# split0_test_Precision                                           0.728125
# split1_test_Precision                                           0.634694
# split2_test_Precision                                            0.62963
# split3_test_Precision                                           0.621032
# split4_test_Precision                                           0.724919
# mean_test_Precision                                              0.66768
# std_test_Precision                                             0.0482533
# rank_test_Precision                                                 2089
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                     989   \
# split0_test_Precision                                           0.728125
# split1_test_Precision                                           0.634694
# split2_test_Precision                                            0.62963
# split3_test_Precision                                           0.621032
# split4_test_Precision                                           0.724919
# mean_test_Precision                                              0.66768
# std_test_Precision                                             0.0482533
# rank_test_Precision                                                 2089
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
#                                                                     987
# split0_test_Precision                                           0.728125
# split1_test_Precision                                           0.634694
# split2_test_Precision                                            0.62963
# split3_test_Precision                                           0.621032
# split4_test_Precision                                           0.724919
# mean_test_Precision                                              0.66768
# std_test_Precision                                             0.0482533
# rank_test_Precision                                                 2089
# params                 {'decision_tree__criterion': 'gini', 'decision...
#
# [9 rows x 2160 columns]

# %% [markdown]
# ### Display Decision Tree
#
# **Note:** You may have to scroll to view

# %%
graph = Source(tree.export_graphviz(clf, out_file=None, feature_names=X.columns, class_names=['spam', 'ham'], filled = True))

display(SVG(graph.pipe(format='svg')))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/graphviz/backend.py in run(cmd, input, capture_output, check, encoding, quiet, **kwargs)
#     163     try:
# --> 164         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     165     except OSError as e:
#
# ~Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     768                                 errread, errwrite,
# --> 769                                 restore_signals, start_new_session)
#     770         except:
#
# ~Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1515                             err_msg += ': ' + repr(err_filename)
# -> 1516                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1517                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dot': 'dot'
#
# During handling of the above exception, another exception occurred:
#
# ExecutableNotFound                        Traceback (most recent call last)
# <ipython-input-208-412a7262fb29> in <module>
#       1 graph = Source(tree.export_graphviz(clf, out_file=None, feature_names=X.columns, class_names=['spam', 'ham'], filled = True))
#       2
# ----> 3 display(SVG(graph.pipe(format='svg')))
#
# ~Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/graphviz/files.py in pipe(self, format, renderer, formatter, quiet)
#     136         out = backend.pipe(self._engine, format, data,
#     137                            renderer=renderer, formatter=formatter,
# --> 138                            quiet=quiet)
#     139
#     140         return out
#
# ~Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/graphviz/backend.py in pipe(engine, format, data, renderer, formatter, quiet)
#     242     """
#     243     cmd, _ = command(engine, format, None, renderer, formatter)
# --> 244     out, _ = run(cmd, input=data, capture_output=True, check=True, quiet=quiet)
#     245     return out
#     246
#
# ~Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/graphviz/backend.py in run(cmd, input, capture_output, check, encoding, quiet, **kwargs)
#     165     except OSError as e:
#     166         if e.errno == errno.ENOENT:
# --> 167             raise ExecutableNotFound(cmd)
#     168         else:
#     169             raise
#
# ExecutableNotFound: failed to execute ['dot', '-Tsvg'], make sure the Graphviz executables are on your systems' PATH
